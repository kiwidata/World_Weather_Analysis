# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import time
from datetime import datetime

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | deputatskiy
# Processing Record 7 of Set 1 | berdigestyakh
# Processing Record 8 of Set 1 | rudbar
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | gold coast
# Processing Record 12 of Set 1 | caravelas
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | harnosand
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | olinda
# Processing Record 17 of Set 1 | college
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | enshi
# Processing Record 22 of Set 1 | salcioara
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | heihe
# Processing Record 29 of Set 1 | usinsk
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | port-gentil
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | ostrovnoy
# Processing Record 35 of Set 1 | azare
# Processing Record 36 of Set 1 | broken hill
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | tubuala
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | sungaipenuh
# Processing Record 42 of Set 1 | yangjiang
# Processing Record 43 of Set 1 | zharkent
# Processing Record 44 of Set 1 | santiago del estero
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | kamenka
# Processing Record 47 of Set 1 | te anau
# Processing Record 48 of Set 1 | bellevue
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | viransehir
# Processing Record 1 of Set 2 | kingsland
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | nueva loja
# Processing Record 4 of Set 2 | lisakovsk
# Processing Record 5 of Set 2 | shakhovskaya
# Processing Record 6 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 2 | oksfjord
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | shingu
# Processing Record 13 of Set 2 | cayenne
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | campoverde
# Processing Record 16 of Set 2 | ballina
# Processing Record 17 of Set 2 | harper
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | lasa
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | imeni poliny osipenko
# Processing Record 23 of Set 2 | jumla
# Processing Record 24 of Set 2 | portpatrick
# City not found. Skipping...
# Processing Record 25 of Set 2 | wenatchee
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | champerico
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | nabire
# Processing Record 34 of Set 2 | kavaratti
# Processing Record 35 of Set 2 | san ramon
# Processing Record 36 of Set 2 | krasnoselkup
# Processing Record 37 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | mayumba
# Processing Record 41 of Set 2 | kokkola
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | kysyl-syr
# Processing Record 44 of Set 2 | komsomolskiy
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | kjollefjord
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | lazaro cardenas
# Processing Record 49 of Set 2 | eureka
# Processing Record 50 of Set 2 | nyaunglebin
# Processing Record 1 of Set 3 | masuguru
# Processing Record 2 of Set 3 | darhan
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | itapetininga
# Processing Record 6 of Set 3 | kaoma
# Processing Record 7 of Set 3 | hami
# Processing Record 8 of Set 3 | kuching
# Processing Record 9 of Set 3 | marawi
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | turkistan
# Processing Record 13 of Set 3 | senekal
# Processing Record 14 of Set 3 | alta floresta
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | cao bang
# Processing Record 19 of Set 3 | peleduy
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | arica
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | bonfim
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | naze
# Processing Record 28 of Set 3 | cerqueira cesar
# Processing Record 29 of Set 3 | kuito
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | portoferraio
# Processing Record 32 of Set 3 | makakilo city
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | caninde
# Processing Record 37 of Set 3 | antofagasta
# Processing Record 38 of Set 3 | abu dhabi
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | yar-sale
# Processing Record 41 of Set 3 | zhigalovo
# Processing Record 42 of Set 3 | pontianak
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | las cruces
# Processing Record 46 of Set 3 | gornopravdinsk
# Processing Record 47 of Set 3 | port hedland
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | lata
# Processing Record 50 of Set 3 | forio
# Processing Record 1 of Set 4 | baculin
# Processing Record 2 of Set 4 | peterhead
# Processing Record 3 of Set 4 | santa maria
# Processing Record 4 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 4 | padang
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | natchitoches
# Processing Record 8 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 4 | steamboat springs
# Processing Record 12 of Set 4 | keetmanshoop
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | kamiiso
# Processing Record 16 of Set 4 | zihuatanejo
# Processing Record 17 of Set 4 | grimari
# City not found. Skipping...
# Processing Record 18 of Set 4 | ingham
# Processing Record 19 of Set 4 | salo
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | kavieng
# Processing Record 24 of Set 4 | gallup
# Processing Record 25 of Set 4 | saint-jean-de-maurienne
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | qaanaaq
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | tigil
# Processing Record 30 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | ternate
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | muisne
# Processing Record 35 of Set 4 | dmytrivka
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | nioro
# Processing Record 38 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 4 | acari
# Processing Record 40 of Set 4 | kandrian
# Processing Record 41 of Set 4 | wakkanai
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | vao
# Processing Record 44 of Set 4 | mogadishu
# Processing Record 45 of Set 4 | meulaboh
# Processing Record 46 of Set 4 | mount isa
# Processing Record 47 of Set 4 | beringovskiy
# Processing Record 48 of Set 4 | celestun
# Processing Record 49 of Set 4 | sohagpur
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | boueni
# Processing Record 2 of Set 5 | shamkhal
# Processing Record 3 of Set 5 | mkushi
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | kaeo
# Processing Record 6 of Set 5 | norman wells
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | urumqi
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | marystown
# Processing Record 11 of Set 5 | ouesso
# Processing Record 12 of Set 5 | pahrump
# Processing Record 13 of Set 5 | joensuu
# Processing Record 14 of Set 5 | port alfred
# Processing Record 15 of Set 5 | waipawa
# Processing Record 16 of Set 5 | porterville
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | maxixe
# Processing Record 19 of Set 5 | dicabisagan
# Processing Record 20 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 5 | san cristobal
# Processing Record 22 of Set 5 | la seyne-sur-mer
# Processing Record 23 of Set 5 | wairoa
# Processing Record 24 of Set 5 | hovd
# Processing Record 25 of Set 5 | veraval
# Processing Record 26 of Set 5 | arman
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | pueblo
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 5 | burgos
# Processing Record 33 of Set 5 | velten
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | narsaq
# Processing Record 36 of Set 5 | baraboo
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | black forest
# Processing Record 40 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 41 of Set 5 | chacabuco
# Processing Record 42 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | charters towers
# Processing Record 45 of Set 5 | vila
# Processing Record 46 of Set 5 | evanston
# Processing Record 47 of Set 5 | mayor pablo lagerenza
# Processing Record 48 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 5 | nemuro
# Processing Record 50 of Set 5 | batemans bay
# Processing Record 1 of Set 6 | pacific grove
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | kyabram
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | cortez
# Processing Record 7 of Set 6 | port lincoln
# Processing Record 8 of Set 6 | chivolo
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | oranjemund
# Processing Record 11 of Set 6 | cotonou
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | hemnesberget
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | cervo
# Processing Record 16 of Set 6 | iroquois falls
# Processing Record 17 of Set 6 | inuvik
# Processing Record 18 of Set 6 | sile
# Processing Record 19 of Set 6 | ozernovskiy
# Processing Record 20 of Set 6 | villa carlos paz
# Processing Record 21 of Set 6 | upernavik
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | primorsk
# Processing Record 27 of Set 6 | kurilsk
# Processing Record 28 of Set 6 | pitimbu
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | carnarvon
# Processing Record 31 of Set 6 | julio de castilhos
# Processing Record 32 of Set 6 | mishan
# Processing Record 33 of Set 6 | acapulco
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | portage
# Processing Record 38 of Set 6 | luderitz
# Processing Record 39 of Set 6 | igrim
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | luwuk
# Processing Record 42 of Set 6 | koungheul
# Processing Record 43 of Set 6 | goya
# Processing Record 44 of Set 6 | navoloki
# Processing Record 45 of Set 6 | chicama
# Processing Record 46 of Set 6 | souillac
# Processing Record 47 of Set 6 | qasigiannguit
# Processing Record 48 of Set 6 | marbella
# Processing Record 49 of Set 6 | peringat
# Processing Record 50 of Set 6 | okoneshnikovo
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | kovur
# Processing Record 3 of Set 7 | xining
# Processing Record 4 of Set 7 | lagoa
# Processing Record 5 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 7 | neiafu
# Processing Record 7 of Set 7 | rosario oeste
# Processing Record 8 of Set 7 | quesnel
# Processing Record 9 of Set 7 | baykit
# Processing Record 10 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | sulangan
# Processing Record 13 of Set 7 | sola
# Processing Record 14 of Set 7 | tuatapere
# Processing Record 15 of Set 7 | poronaysk
# Processing Record 16 of Set 7 | cuajinicuilapa
# Processing Record 17 of Set 7 | bathsheba
# Processing Record 18 of Set 7 | valparaiso
# Processing Record 19 of Set 7 | araouane
# Processing Record 20 of Set 7 | pedreiras
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | akureyri
# Processing Record 23 of Set 7 | port hardy
# Processing Record 24 of Set 7 | kyshtovka
# Processing Record 25 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 7 | ixtapa
# Processing Record 27 of Set 7 | we
# City not found. Skipping...
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | bolshaya irba
# City not found. Skipping...
# Processing Record 31 of Set 7 | berlevag
# Processing Record 32 of Set 7 | blackwater
# Processing Record 33 of Set 7 | dongsheng
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | opuwo
# Processing Record 36 of Set 7 | erenhot
# Processing Record 37 of Set 7 | sneek
# Processing Record 38 of Set 7 | aswan
# Processing Record 39 of Set 7 | mionica
# Processing Record 40 of Set 7 | eydhafushi
# Processing Record 41 of Set 7 | grand-lahou
# Processing Record 42 of Set 7 | bereda
# Processing Record 43 of Set 7 | sugod
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | ponta delgada
# Processing Record 46 of Set 7 | baturaja
# Processing Record 47 of Set 7 | aksu
# Processing Record 48 of Set 7 | conceicao do araguaia
# Processing Record 49 of Set 7 | bhanjanagar
# Processing Record 50 of Set 7 | shyryayeve
# Processing Record 1 of Set 8 | kahului
# Processing Record 2 of Set 8 | santa flavia
# Processing Record 3 of Set 8 | bembereke
# Processing Record 4 of Set 8 | wittmund
# Processing Record 5 of Set 8 | udachnyy
# Processing Record 6 of Set 8 | esil
# Processing Record 7 of Set 8 | socorro
# Processing Record 8 of Set 8 | codajas
# Processing Record 9 of Set 8 | north bend
# Processing Record 10 of Set 8 | awjilah
# Processing Record 11 of Set 8 | boa vista
# Processing Record 12 of Set 8 | zaqatala
# Processing Record 13 of Set 8 | alofi
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | mokrous
# Processing Record 16 of Set 8 | torres
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 19 of Set 8 | iranshahr
# Processing Record 20 of Set 8 | lensk
# Processing Record 21 of Set 8 | novomykolayivka
# Processing Record 22 of Set 8 | merauke
# Processing Record 23 of Set 8 | saskylakh
# Processing Record 24 of Set 8 | sumbe
# Processing Record 25 of Set 8 | maniitsoq
# Processing Record 26 of Set 8 | kruisfontein
# Processing Record 27 of Set 8 | manokwari
# Processing Record 28 of Set 8 | grandview
# Processing Record 29 of Set 8 | buraydah
# Processing Record 30 of Set 8 | havre-saint-pierre
# Processing Record 31 of Set 8 | deniliquin
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | puerto ayora
# Processing Record 34 of Set 8 | miandoab
# Processing Record 35 of Set 8 | grahamstown
# Processing Record 36 of Set 8 | fort-shevchenko
# Processing Record 37 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 38 of Set 8 | tiznit
# Processing Record 39 of Set 8 | erice
# Processing Record 40 of Set 8 | turukhansk
# Processing Record 41 of Set 8 | bozhou
# Processing Record 42 of Set 8 | saint-joseph
# Processing Record 43 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | coari
# Processing Record 46 of Set 8 | goure
# Processing Record 47 of Set 8 | salym
# Processing Record 48 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 8 | suntar
# Processing Record 50 of Set 8 | mahibadhoo
# Processing Record 1 of Set 9 | kyzyl-suu
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | ishigaki
# Processing Record 4 of Set 9 | teguise
# Processing Record 5 of Set 9 | santo domingo
# Processing Record 6 of Set 9 | chiria
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | talaya
# Processing Record 9 of Set 9 | constantine
# Processing Record 10 of Set 9 | ati
# Processing Record 11 of Set 9 | maragogi
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 14 of Set 9 | gao
# Processing Record 15 of Set 9 | tuy hoa
# Processing Record 16 of Set 9 | shar
# Processing Record 17 of Set 9 | saint-francois
# Processing Record 18 of Set 9 | svetlaya
# Processing Record 19 of Set 9 | pundaguitan
# Processing Record 20 of Set 9 | honiara
# Processing Record 21 of Set 9 | road town
# Processing Record 22 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 9 | flinders
# Processing Record 24 of Set 9 | walvis bay
# Processing Record 25 of Set 9 | bratskoye
# Processing Record 26 of Set 9 | haines junction
# Processing Record 27 of Set 9 | bentong
# Processing Record 28 of Set 9 | lethem
# Processing Record 29 of Set 9 | amapa
# Processing Record 30 of Set 9 | gazli
# Processing Record 31 of Set 9 | tamiahua
# Processing Record 32 of Set 9 | huarmey
# Processing Record 33 of Set 9 | san vicente
# Processing Record 34 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | vancouver
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | abha
# Processing Record 38 of Set 9 | ippy
# Processing Record 39 of Set 9 | portland
# Processing Record 40 of Set 9 | laguna
# Processing Record 41 of Set 9 | garowe
# Processing Record 42 of Set 9 | smithers
# Processing Record 43 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 9 | bolhrad
# Processing Record 45 of Set 9 | balykshi
# Processing Record 46 of Set 9 | ugoofaaru
# Processing Record 47 of Set 9 | norfolk
# Processing Record 48 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | bauchi
# Processing Record 50 of Set 9 | highland springs
# Processing Record 1 of Set 10 | nabinagar
# Processing Record 2 of Set 10 | nata
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | oyama
# Processing Record 5 of Set 10 | ostersund
# Processing Record 6 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 10 | onokhino
# Processing Record 8 of Set 10 | wanning
# Processing Record 9 of Set 10 | tynda
# Processing Record 10 of Set 10 | tiksi
# Processing Record 11 of Set 10 | vassouras
# Processing Record 12 of Set 10 | huainan
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | ola
# Processing Record 15 of Set 10 | kouroussa
# Processing Record 16 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 17 of Set 10 | ust-kan
# Processing Record 18 of Set 10 | coihaique
# Processing Record 19 of Set 10 | odweyne
# Processing Record 20 of Set 10 | najran
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | fort nelson
# Processing Record 23 of Set 10 | arrecife
# Processing Record 24 of Set 10 | sabzevar
# Processing Record 25 of Set 10 | podporozhye
# Processing Record 26 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 10 | lerwick
# Processing Record 28 of Set 10 | guapi
# Processing Record 29 of Set 10 | san isidro
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | la asuncion
# Processing Record 32 of Set 10 | bisalpur
# Processing Record 33 of Set 10 | coahuayana
# Processing Record 34 of Set 10 | nyurba
# Processing Record 35 of Set 10 | sesheke
# Processing Record 36 of Set 10 | san carlos de bariloche
# Processing Record 37 of Set 10 | cap malheureux
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | kichera
# Processing Record 40 of Set 10 | nouadhibou
# Processing Record 41 of Set 10 | calama
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | rawson
# Processing Record 44 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 10 | thunder bay
# Processing Record 46 of Set 10 | floro
# Processing Record 47 of Set 10 | nago
# Processing Record 48 of Set 10 | saint anthony
# Processing Record 49 of Set 10 | navapur
# City not found. Skipping...
# Processing Record 50 of Set 10 | lulea
# Processing Record 1 of Set 11 | labuhan
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | qingyuan
# Processing Record 4 of Set 11 | bethanien
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | rio gallegos
# Processing Record 7 of Set 11 | prado
# Processing Record 8 of Set 11 | samarai
# Processing Record 9 of Set 11 | batticaloa
# Processing Record 10 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 11 of Set 11 | mehamn
# Processing Record 12 of Set 11 | rehli
# Processing Record 13 of Set 11 | bermeo
# Processing Record 14 of Set 11 | naivasha
# Processing Record 15 of Set 11 | grindavik
# Processing Record 16 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 11 | cerro largo
# Processing Record 19 of Set 11 | khovu-aksy
# Processing Record 20 of Set 11 | njombe
# Processing Record 21 of Set 11 | tyrma
# Processing Record 22 of Set 11 | byron bay
# Processing Record 23 of Set 11 | kaka
# Processing Record 24 of Set 11 | shelburne
# Processing Record 25 of Set 11 | la ronge
# Processing Record 26 of Set 11 | blytheville
# Processing Record 27 of Set 11 | praia
# Processing Record 28 of Set 11 | mao
# Processing Record 29 of Set 11 | bilma
# Processing Record 30 of Set 11 | rocha
# Processing Record 31 of Set 11 | yulara
# Processing Record 32 of Set 11 | bani
# Processing Record 33 of Set 11 | sur
# Processing Record 34 of Set 11 | hervey bay
# Processing Record 35 of Set 11 | saraland
# Processing Record 36 of Set 11 | havelock
# Processing Record 37 of Set 11 | hobyo
# Processing Record 38 of Set 11 | marang
# Processing Record 39 of Set 11 | dongobesh
# Processing Record 40 of Set 11 | tura
# Processing Record 41 of Set 11 | vestmannaeyjar
# Processing Record 42 of Set 11 | northam
# Processing Record 43 of Set 11 | ust-maya
# Processing Record 44 of Set 11 | minot
# Processing Record 45 of Set 11 | matara
# Processing Record 46 of Set 11 | lahan
# Processing Record 47 of Set 11 | santa marinella
# Processing Record 48 of Set 11 | puerto leguizamo
# Processing Record 49 of Set 11 | anito
# Processing Record 50 of Set 11 | hanzhong
# Processing Record 1 of Set 12 | karasburg
# Processing Record 2 of Set 12 | high level
# Processing Record 3 of Set 12 | namatanai
# Processing Record 4 of Set 12 | muzhi
# Processing Record 5 of Set 12 | alamos
# Processing Record 6 of Set 12 | flin flon
# Processing Record 7 of Set 12 | goderich
# Processing Record 8 of Set 12 | dingle
# Processing Record 9 of Set 12 | omaruru
# Processing Record 10 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 12 | oktyabrskoye
# Processing Record 12 of Set 12 | omboue
# Processing Record 13 of Set 12 | leh
# Processing Record 14 of Set 12 | zabol
# Processing Record 15 of Set 12 | bassila
# Processing Record 16 of Set 12 | farsund
# Processing Record 17 of Set 12 | formiga
# Processing Record 18 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 12 | toul
# Processing Record 20 of Set 12 | sao miguel do araguaia
# Processing Record 21 of Set 12 | auburn
# Processing Record 22 of Set 12 | barkly west
# Processing Record 23 of Set 12 | tual
# Processing Record 24 of Set 12 | asfi
# Processing Record 25 of Set 12 | maningrida
# Processing Record 26 of Set 12 | clermont
# Processing Record 27 of Set 12 | jibuti
# Processing Record 28 of Set 12 | mukhen
# Processing Record 29 of Set 12 | trat
# Processing Record 30 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | fare
# Processing Record 33 of Set 12 | deutsch-wagram
# Processing Record 34 of Set 12 | quetzaltepec
# City not found. Skipping...
# Processing Record 35 of Set 12 | benguela
# Processing Record 36 of Set 12 | yuzawa
# Processing Record 37 of Set 12 | pochutla
# Processing Record 38 of Set 12 | vagur
# Processing Record 39 of Set 12 | sakakah
# Processing Record 40 of Set 12 | hammerfest
# Processing Record 41 of Set 12 | kindu
# Processing Record 42 of Set 12 | saint george
# Processing Record 43 of Set 12 | darnah
# Processing Record 44 of Set 12 | yuanping
# Processing Record 45 of Set 12 | novo aripuana
# Processing Record 46 of Set 12 | talnakh
# Processing Record 47 of Set 12 | nuuk
# Processing Record 48 of Set 12 | ciudad bolivar
# Processing Record 49 of Set 12 | hambantota
# Processing Record 50 of Set 12 | margate
# Processing Record 1 of Set 13 | morondava
# Processing Record 2 of Set 13 | umm lajj
# Processing Record 3 of Set 13 | nizwa
# Processing Record 4 of Set 13 | whyalla
# Processing Record 5 of Set 13 | evensk
# Processing Record 6 of Set 13 | paducah
# Processing Record 7 of Set 13 | le port
# Processing Record 8 of Set 13 | hanko
# Processing Record 9 of Set 13 | candolim
# Processing Record 10 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 11 of Set 13 | tongliao
# Processing Record 12 of Set 13 | nouakchott
# Processing Record 13 of Set 13 | bom jesus
# Processing Record 14 of Set 13 | las vegas
# Processing Record 15 of Set 13 | los llanos de aridane
# Processing Record 16 of Set 13 | yoichi
# Processing Record 17 of Set 13 | kirakira
# Processing Record 18 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | kasongo-lunda
# Processing Record 20 of Set 13 | egvekinot
# Processing Record 21 of Set 13 | manitowoc
# Processing Record 22 of Set 13 | bani walid
# Processing Record 23 of Set 13 | vuktyl
# Processing Record 24 of Set 13 | avera
# Processing Record 25 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 13 | ifakara
# Processing Record 27 of Set 13 | kermanshah
# Processing Record 28 of Set 13 | chapais
# Processing Record 29 of Set 13 | bintulu
# Processing Record 30 of Set 13 | hirara
# Processing Record 31 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 13 | rawlins
# Processing Record 33 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 13 | colares
# Processing Record 35 of Set 13 | imbituba
# Processing Record 36 of Set 13 | puerto baquerizo moreno
# Processing Record 37 of Set 13 | nelson bay
# Processing Record 38 of Set 13 | alice springs
# Processing Record 39 of Set 13 | bria
# Processing Record 40 of Set 13 | jinchang
# Processing Record 41 of Set 13 | gravdal
# Processing Record 42 of Set 13 | ilmajoki
# Processing Record 43 of Set 13 | sainte-maxime
# Processing Record 44 of Set 13 | hun
# Processing Record 45 of Set 13 | diego de almagro
# Processing Record 46 of Set 13 | verkhnyaya inta
# Processing Record 47 of Set 13 | darfo
# Processing Record 48 of Set 13 | guerrero negro
# Processing Record 49 of Set 13 | amga
# Processing Record 50 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 14 | minsk
# Processing Record 2 of Set 14 | okha
# Processing Record 3 of Set 14 | istok
# Processing Record 4 of Set 14 | nguru
# Processing Record 5 of Set 14 | malartic
# Processing Record 6 of Set 14 | boyolangu
# Processing Record 7 of Set 14 | pacifica
# Processing Record 8 of Set 14 | ambovombe
# Processing Record 9 of Set 14 | fairbanks
# Processing Record 10 of Set 14 | damara
# Processing Record 11 of Set 14 | shache
# Processing Record 12 of Set 14 | marsa matruh
# Processing Record 13 of Set 14 | sao lourenco do sul
# Processing Record 14 of Set 14 | kidal
# Processing Record 15 of Set 14 | methven
# Processing Record 16 of Set 14 | srednekolymsk
# Processing Record 17 of Set 14 | adrar
# Processing Record 18 of Set 14 | sobolevo
# Processing Record 19 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 14 | gumdag
# Processing Record 21 of Set 14 | sao mateus do sul
# Processing Record 22 of Set 14 | mayo
# Processing Record 23 of Set 14 | lorengau
# Processing Record 24 of Set 14 | bitung
# Processing Record 25 of Set 14 | thanh hoa
# Processing Record 26 of Set 14 | guane
# Processing Record 27 of Set 14 | lubbock
# Processing Record 28 of Set 14 | kadipur
# Processing Record 29 of Set 14 | carmo do paranaiba
# Processing Record 30 of Set 14 | inhambane
# Processing Record 31 of Set 14 | henties bay
# Processing Record 32 of Set 14 | puerto escondido
# Processing Record 33 of Set 14 | sept-iles
# Processing Record 34 of Set 14 | kitgum
# Processing Record 35 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 14 | luwingu
# Processing Record 37 of Set 14 | desaguadero
# Processing Record 38 of Set 14 | holguin
# Processing Record 39 of Set 14 | sambava
# Processing Record 40 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 14 | porto torres
# Processing Record 42 of Set 14 | hutchinson
# Processing Record 43 of Set 14 | montoro
# Processing Record 44 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 14 | creel
# Processing Record 46 of Set 14 | tessalit
# Processing Record 47 of Set 14 | aguas vermelhas
# Processing Record 48 of Set 14 | gigmoto
# Processing Record 49 of Set 14 | areia branca
# Processing Record 50 of Set 14 | amberley
# Processing Record 1 of Set 15 | rabo de peixe
# Processing Record 2 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 15 | rincon
# Processing Record 4 of Set 15 | wagga wagga
# Processing Record 5 of Set 15 | coolum beach
# Processing Record 6 of Set 15 | mamallapuram
# Processing Record 7 of Set 15 | solnechnyy
# Processing Record 8 of Set 15 | mareeba
# Processing Record 9 of Set 15 | praya
# Processing Record 10 of Set 15 | itoman
# Processing Record 11 of Set 15 | erzin
# Processing Record 12 of Set 15 | beloha
# Processing Record 13 of Set 15 | vodnyy
# Processing Record 14 of Set 15 | vilyuysk
# Processing Record 15 of Set 15 | the valley
# Processing Record 16 of Set 15 | arinos
# Processing Record 17 of Set 15 | port blair
# Processing Record 18 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 15 | antalaha
# Processing Record 20 of Set 15 | vardo
# Processing Record 21 of Set 15 | shakawe
# Processing Record 22 of Set 15 | mantua
# Processing Record 23 of Set 15 | orange
# Processing Record 24 of Set 15 | burica
# City not found. Skipping...
# Processing Record 25 of Set 15 | elat
# Processing Record 26 of Set 15 | aguimes
# Processing Record 27 of Set 15 | spornoye
# Processing Record 28 of Set 15 | barreirinhas
# Processing Record 29 of Set 15 | lieksa
# Processing Record 30 of Set 15 | alenquer
# Processing Record 31 of Set 15 | upata
# Processing Record 32 of Set 15 | storforshei
# Processing Record 33 of Set 15 | bad sassendorf
# Processing Record 34 of Set 15 | skelleftea
# Processing Record 35 of Set 15 | ust-tsilma
# Processing Record 36 of Set 15 | bonavista
# Processing Record 37 of Set 15 | bandipur
# Processing Record 38 of Set 15 | dingzhou
# Processing Record 39 of Set 15 | ukiah
# Processing Record 40 of Set 15 | curup
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 672

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mar Del Plata -38.0023  -57.5575    290.98        98          40
# 1          Barrow  71.2906 -156.7887    256.16        78         100
# 2  Saint-Philippe -21.3585   55.7679    294.92        78          36
# 3           Airai  -8.9266  125.4092    294.60        71          58
# 4     Deputatskiy  69.3000  139.9000    234.54        95          60
# 5   Berdigestyakh  62.0989  126.6992    229.44       100          61
# 6          Rudbar  30.1500   62.6000    286.34        22           3
# 7    Ponta Do Sol  32.6667  -17.1000    292.43        76          29
# 8          Albany  42.6001  -73.9662    279.99        66           0
# 9      Gold Coast -28.0000  153.4333    302.73        72          40
#
#    Wind Speed Country Current Description
# 0        6.26      AR    scattered clouds
# 1        2.57      US          light snow
# 2        4.52      RE    scattered clouds
# 3        1.08      TL       broken clouds
# 4        2.16      RU       broken clouds
# 5        0.59      RU       broken clouds
# 6        0.66      AF           clear sky
# 7        0.99      PT    scattered clouds
# 8        3.08      US           clear sky
# 9        5.66      AU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Mar Del Plata      AR -38.0023  -57.5575    290.98        98
# 1            Barrow      US  71.2906 -156.7887    256.16        78
# 2    Saint-Philippe      RE -21.3585   55.7679    294.92        78
# 3             Airai      TL  -8.9266  125.4092    294.60        71
# 4       Deputatskiy      RU  69.3000  139.9000    234.54        95
# ..              ...     ...      ...       ...       ...       ...
# 667       Bonavista      CA  48.6499  -53.1147    276.64        86
# 668        Bandipur      NP  27.9333   84.4167    282.31        77
# 669        Dingzhou      CN  38.5131  114.9956    275.21        29
# 670           Ukiah      US  39.1502 -123.2078    288.95        61
# 671           Curup      ID  -3.4667  102.5333    295.55        88
#
#      Cloudiness  Wind Speed Current Description
# 0            40        6.26    scattered clouds
# 1           100        2.57          light snow
# 2            36        4.52    scattered clouds
# 3            58        1.08       broken clouds
# 4            60        2.16       broken clouds
# ..          ...         ...                 ...
# 667         100       13.11     overcast clouds
# 668           0        1.12           clear sky
# 669          75        2.93       broken clouds
# 670           0        0.45           clear sky
# 671          96        0.98     overcast clouds
#
# [672 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv('WeatherPy_Database.csv')
